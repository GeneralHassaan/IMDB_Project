# %%
import pymysql
import numpy as np
import pandas as pd
import pandas as pd
import os, json, time
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook
from sqlalchemy import create_engine
pymysql.install_as_MySQLdb()

# %%
filename = 'https://datasets.imdbws.com/title.basics.tsv.gz'
df = pd.read_csv(filename, sep='\t', low_memory=False)

df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# replacing \N
df = df.replace({'\\N':np.nan})

# %%
df= df.dropna(subset = ['runtimeMinutes','genres'])

# %%
df = df.loc[(df['startYear'] >= '2000')]

# %%
df['startYear'] = df['startYear'].astype(float)

# %%
# df.dropna(inplace = True)
# df.head(50)
# Out:
#            tconst     titleType                                primaryTitle  \
# 108563  tt0111056      tvSeries                          Gensomaden Saiyuki
# 137836  tt0142032  tvMiniSeries                                        Dune
# 153556  tt0158466  tvMiniSeries  Anne of Green Gables: The Continuing Story
# 155749  tt0160904      tvSeries                                        MI-5
# 158616  tt0163944  tvMiniSeries                                  Labyrinten
# 162047  tt0167701      tvSeries                Randall & Hopkirk (Deceased)
# 171933  tt0178140  tvMiniSeries                                The Wide Net
# 171953  tt0178161      tvSeries        The Secret Adventures of Jules Verne
# 172796  tt0179051  tvMiniSeries                               Ted and Alice
# 174784  tt0181199  tvMiniSeries                              Arabian Nights
# 179160  tt0185906  tvMiniSeries                            Band of Brothers
# 180743  tt0187621      tvSeries                                       Beast
# 181407  tt0188340      tvSeries                           Kamen Rider Kuuga
# 182284  tt0189303      tvSeries                                   Sauvetage
# 184495  tt0191694      tvSeries                          La grosse émission
# 187234  tt0194608  tvMiniSeries                                 Edderkoppen
# 188425  tt0195896      tvSeries                                    M.Y.O.B.
# 189615  tt0197154  tvMiniSeries                                 Gormenghast
# 190504  tt0198099      tvSeries                                      Daddio
# 191713  tt0199421      tvSeries                               Higher Ground
# 192562  tt0200373      tvSeries                            Secret Agent Man
# 193469  tt0201374  tvMiniSeries                       Anderssons älskarinna
# 194480  tt0202513      tvSeries                                Opposite Sex
# 194670  tt0202724      tvSeries                                        D.C.
# 196599  tt0204765      tvSeries                              City of Angels
# 196819  tt0204993      tvSeries                                  Dark Angel
# 197490  tt0205700      tvSeries                                       Titus
# 198205  tt0206476      tvSeries                              Cleopatra 2525
# 198236  tt0206511      tvSeries                                Even Stevens
# 198957  tt0207275  tvMiniSeries                            The 10th Kingdom
# 200210  tt0208629  tvMiniSeries                                   Nuremberg
# 201083  tt0209557      tvSeries                                  Wonderland
# 201778  tt0210294  tvMiniSeries                                  Snow Queen
# 201892  tt0210413      tvSeries                                      Clerks
# 201916  tt0210438      tvSeries                                Passion Cove
# 203224  tt0211852      tvSeries                                      Ramona
# 203994  tt0212671      tvSeries                       Malcolm in the Middle
# 204002  tt0212679      tvSeries                        My Little Pony Tales
# 204009  tt0212686      tvSeries             Power Rangers Lightspeed Rescue
# 204149  tt0212831      tvSeries                             Brutally Normal
# 204619  tt0213327      tvSeries                                   Andromeda
# 204806  tt0213523      tvSeries                                 Blue Murder
# 206581  tt0215402      tvSeries                                     Control
# 208259  tt0217172      tvSeries                                   The Squad
# 162047             50        Comedy,Crime,Fantasy
# 171933            176         Crime,Drama,Mystery
# 171953             60     Adventure,Horror,Sci-Fi
# 172796            180        Comedy,Drama,Romance
# 174784            175    Adventure,Family,Fantasy
# 179160            594           Drama,History,War
# 180743             29                      Comedy
# 181407             30      Action,Adventure,Drama
# 182284             52                       Drama
# 184495             52            Comedy,Talk-Show
# 187234             58         Crime,Drama,History
# 188425             30                      Comedy
# 189615            232      Adventure,Comedy,Drama
# 190504             30                      Comedy
# 191713             60                       Drama
# 192562             86             Action,Thriller
# 193469            347                       Drama
# 194480             60                Comedy,Drama
# 194670             60                       Drama
# 196599             60                       Drama
# 196819             60        Action,Drama,Mystery
# 197490             23                Comedy,Drama
# 198205             60       Action,Fantasy,Sci-Fi
# 198236             30               Comedy,Family
# 198957            417     Adventure,Comedy,Family
# 200210            180           Drama,History,War
# 201083             50                       Drama
# 201778            180    Adventure,Family,Fantasy
# 201892             22            Animation,Comedy
# 201916             28                Comedy,Drama
# 203224             45               Drama,Romance
# 203994             22               Comedy,Family
# 204002             30  Adventure,Animation,Family
# 204009             30      Action,Adventure,Drama
# 204149             30                      Comedy
# 204619             43      Action,Adventure,Drama
# 204806             60                 Crime,Drama
# 206581             60                  Reality-TV
# 208259             52              Crime,Thriller
# 208640            180           Adventure,Fantasy
# 209006             25                       Drama
# 209769             42                 Documentary
# 210370            171                    Thriller
# 210385            284     Animation,Comedy,Sci-Fi
# 210885            375         Action,Crime,Sci-Fi

# %%
df.titleType.value_counts()
# Out:
# tvEpisode       879985
# short           479525
# movie           221311
# video           149475
# tvSeries         61977
# tvMovie          47585
# tvMiniSeries     12338
# tvSpecial        12329
# tvShort           5712
# videoGame          271
# Name: titleType, dtype: int64

# %%
df.loc[(df['titleType'] == 'movie')]
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 66336    tt0067683     movie
# 67669    tt0069049     movie
# ...            ...       ...
# 9492579  tt9916362     movie
# 9492663  tt9916538     movie
# 9492704  tt9916622     movie
# 9492731  tt9916680     movie
# 9492763  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 66336             Workers '71: Nothing About Us Without Us
# 67669                           The Other Side of the Wind
# ...                                                    ...
# 9492579                                              Coven
# 9492663                                Kuambil Lagi Hatiku
# 9492704        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9492731  De la ilusión al desconcierto: cine colombiano...
# 9492763                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 66336                   Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 67669                           The Other Side of the Wind       0     2018.0
# ...                                                    ...     ...        ...
# 9492579                                           Akelarre       0     2020.0
# 9492663                                Kuambil Lagi Hatiku       0     2019.0
# 9492704        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9492731  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9492763                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN            133             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 66336       NaN             47             Documentary
# 67669       NaN            122                   Drama
# ...         ...            ...                     ...
# 9492579     NaN             92           Drama,History
# 9492663     NaN            123                   Drama
# 9492704     NaN             57             Documentary
# 9492731     NaN            100             Documentary
# 9492763     NaN             49             Documentary
#
# [221311 rows x 9 columns]

# %%
is_documentary = df['genres'].str.contains('documentary',case=False)
df = df[~is_documentary]

# %%
file_2 = 'https://datasets.imdbws.com/title.akas.tsv.gz'
akas = pd.read_csv(file_2, sep='\t', low_memory=False)

# %%
akas = akas.replace({'\\N':np.nan})

# %%
akas.loc[(akas['region'] == 'US')]

# %%
keepers =df['tconst'].isin(akas['titleId'])
keepers

# %%
df = df[keepers]
df

# %%
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")

# %%
df.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
df = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
df.head()

# %% [markdown]
# # PART II

# %%
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (2.9.1)
# Requirement already satisfied: requests in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (from requests->tmdbsimple) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (from requests->tmdbsimple) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (from requests->tmdbsimple) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hassaanasif/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (from requests->tmdbsimple) (3.3)

# %%
import json
with open('/Users/hassaanasif/desktop/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
movie = tmdb.Movies(603)

# %%
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/l4QHerTSbMI7qgvasqxP36pqjN6.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 93.363,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.194,
#  'vote_count': 22542}

# %%
info['budget']
# Out:
# 63000000

# %%
info['revenue']
# Out:
# 463517383

# %%
info['imdb_id']
# Out:
# 'tt0133093'

# %%
# Searching using the IMDB_ID 
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
releases = movie.releases()
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# PG
# PG
# PG

# %%
movie = tmdb.Movies('tt1361336')
# save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()
# Loop through countries in releases
for c in releases['countries']:
    # if the country abbreviation==US
    if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
       info['certification'] = c['certification']

# %%
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies(movie_id)
    
    info = movie.info()
    
    releases = movie.releases()
    
    for c in releases['countries']:
            if c['iso_3166_1'] == 'US':
                info['certification'] = c['certification']
    return info

# %%
get_movie_with_rating("tt0848228")
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 125.101,
#  'poster_path': '/tYqp6vEOo8YlVWrYQvt9nyOhsA2.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.708,
#  'vote_count': 27943,
#  'certification': 'PG-13'}

# %%
import pandas as pd
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except: 
        pass
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Avengers  ...  1518815515      143
# 2                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1                    Some assembly required.  The Avengers  False
# 2  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0         7.708      27943         PG-13
# 1         7.708      27943         PG-13
# 2         7.881      10007         PG-13
#
# [3 rows x 26 columns]

# %%
import pandas as pd
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
errors = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except Exception as e: 
        errors.append([movie_id, e])
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Avengers  ...  1518815515      143
# 2                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1                    Some assembly required.  The Avengers  False
# 2  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0         7.708      27943         PG-13
# 1         7.708      27943         PG-13
# 2         7.881      10007         PG-13
#
# [3 rows x 26 columns]

# %%
print(f"- Number of errors: {len(errors)}")
errors
# Out:
# - Number of errors: 1
# [['tt0115937',
#   requests.exceptions.HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=e7bcd4cc5a917ccd01b193357257ecea')]]

# %%
import os, time,json
import tmdbsimple as tmdb 
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title_basics.csv.gz']

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
YEARS_TO_GET = [2000,2001]

# %%
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    # If it does not exist: create it
    if file_exists == False:
# save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
            #Saving new year as the current df
            basics = df.loc[ df['startYear']==YEAR].copy()
    # saving movie ids to list
            movie_ids = df['tconst'].copy()
        
    # INNER Loop
            for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
                try:
            # Retrieve then data for the movie id
                    temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
                    write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
                    time.sleep(0.02)
            
                except Exception as e:
                    errors.append([movie_id, e])
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

# %%
print(f"- Total errors: {len(errors)}")
# Out:
# - Total errors: 1

# %%
previous_df = pd.read_json(JSON_FILE)
